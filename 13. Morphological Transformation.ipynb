# %%
# Morphological transformation are some simple operation based on the image shape

# %%
# A kernel tells you how to change the value of 
# any given pixel by combining it with different
# amounts of the neighboring pixels.

# %%
import numpy as np
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib line
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-53b99a520bc4> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 get_ipython().run_line_magic('matplotlib', 'line')
#
# ~\anaconda3\envs\CV\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# <decorator-gen-109> in matplotlib(self, line)
#
# ~\anaconda3\envs\CV\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\CV\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~\anaconda3\envs\CV\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    3417         """
#    3418         from IPython.core import pylabtools as pt
# -> 3419         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3420
#    3421         if gui != 'inline':
#
# ~\anaconda3\envs\CV\lib\site-packages\IPython\core\pylabtools.py in find_gui_and_backend(gui, gui_select)
#     282     if gui and gui != 'auto':
#     283         # select backend based on requested gui
# --> 284         backend = backends[gui]
#     285         if gui == 'agg':
#     286             gui = None
#
# KeyError: 'line'

# %%
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
titles = ['image']
images = [img]

for i in range(1):
    plt.subplot(1,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
_,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)
titles = ['image','mask']
images = [img,mask]

for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
# we can see some black dots on white balls so 
# lets remove them

# %%
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
_,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2),np.uint8)
dilation = cv2.dilate(mask,kernal)

titles = ['image','mask','dilation']
images = [img,mask,dilation]

for i in range(3):
    plt.figure(figsize=(18,12))
    plt.subplot(3,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
# still some dots are there so lets remove them completely

# %%
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
_,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2),np.uint8)
dilation = cv2.dilate(mask,kernal,iterations = 2)

titles = ['image','mask','dilation']
images = [img,mask,dilation]

for i in range(3):
    plt.figure(figsize=(18,12))
    plt.subplot(3,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
# Erosion

# %%
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
_,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2),np.uint8)
dilation = cv2.dilate(mask,kernal,iterations = 2)
erosion = cv2.erode(mask,kernal,iterations=1)

titles = ['image','mask','dilation','erosion']
images = [img,mask,dilation,erosion]

for i in range(4):
    plt.figure(figsize=(18,12))
    plt.subplot(4,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
_,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2),np.uint8)
dilation = cv2.dilate(mask,kernal,iterations = 2)
erosion = cv2.erode(mask,kernal,iterations=3)

titles = ['image','mask','dilation','erosion']
images = [img,mask,dilation,erosion]

for i in range(4):
    plt.figure(figsize=(18,12))
    plt.subplot(4,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
# opening (erosion then dilation)
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
_,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2),np.uint8)
dilation = cv2.dilate(mask,kernal,iterations = 2)
erosion = cv2.erode(mask,kernal,iterations=3)
opening = cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernal)

titles = ['image','mask','dilation','erosion','opening']
images = [img,mask,dilation,erosion,opening]

for i in range(5):
    plt.figure(figsize=(18,12))
    plt.subplot(5,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
# closing (dilation then erosion)
# opening (erosion then dilation)
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
_,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2),np.uint8)
dilation = cv2.dilate(mask,kernal,iterations = 2)
erosion = cv2.erode(mask,kernal,iterations=3)
opening = cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernal)
closing= cv2.morphologyEx(mask,cv2.MORPH_CLOSE,kernal)

titles = ['image','mask','dilation','erosion','opening','closing']
images = [img,mask,dilation,erosion,opening,closing]

for i in range(6):
    plt.figure(figsize=(12,8))
    plt.subplot(3,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
# some more methods
# closing (dilation then erosion)
# opening (erosion then dilation)
img = cv2.imread('Images/smarties.png',cv2.IMREAD_GRAYSCALE)
_,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2),np.uint8)
dilation = cv2.dilate(mask,kernal,iterations = 2)
erosion = cv2.erode(mask,kernal,iterations=3)
opening = cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernal)
closing= cv2.morphologyEx(mask,cv2.MORPH_CLOSE,kernal)
mg= cv2.morphologyEx(mask,cv2.MORPH_GRADIENT,kernal)
th= cv2.morphologyEx(mask,cv2.MORPH_TOPHAT,kernal)


titles = ['image','mask','dilation','erosion','opening','closing','mg','th']
images = [img,mask,dilation,erosion,opening,closing,mg,th]

for i in range(8):
    plt.figure(figsize=(30,15))
    plt.subplot(8,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
# other example
# some more methods
# closing (dilation then erosion)
# opening (erosion then dilation)
img = cv2.imread('Images/j.png',cv2.IMREAD_GRAYSCALE)


kernal = np.ones((2,2),np.uint8)
dilation = cv2.dilate(img,kernal,iterations = 2)
erosion = cv2.erode(img,kernal,iterations=3)
opening = cv2.morphologyEx(img,cv2.MORPH_OPEN,kernal)
closing= cv2.morphologyEx(img,cv2.MORPH_CLOSE,kernal)
mg= cv2.morphologyEx(img,cv2.MORPH_GRADIENT,kernal)
th= cv2.morphologyEx(img,cv2.MORPH_TOPHAT,kernal)


titles = ['image','mask','dilation','erosion','opening','closing','mg','th']
images = [img,img,dilation,erosion,opening,closing,mg,th]

for i in range(8):
    plt.figure(figsize=(30,15))
    plt.subplot(8,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
